# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("../data/Library_Usage.csv", 
    na_values="none")
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 1               Juvenile                0               0
# 1                 2                   Teen                0               0
# 2                 0                  Adult                0               0
# 3                 2                   Teen                0               0
# 4                 2                   Teen                0               0
#
#         Age Range Home Library Code Home Library Definition  \
# 0    0 to 9 years                r3                Richmond
# 1  10 to 19 years                 x                    Main
# 2  35 to 44 years                m4                  Merced
# 3  10 to 19 years                 x                    Main
# 4  10 to 19 years                b2                 Bayview
#
#   Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                      NaN                      NaN                      z
# 1                      NaN                      NaN                      z
# 2                      NaN                      NaN                      z
# 3                      NaN                      NaN                      z
# 4                      NaN                      NaN                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        Email                    True
# 1                        Email                    True
# 2                        Email                    True
# 3                        Email                    True
# 4                        Email                    True
#
#    Year Patron Registered  Within San Francisco County
# 0                    2022                         True
# 1                    2022                         True
# 2                    2019                         True
# 3                    2021                         True
# 4                    2013                         True

# %% [markdown]
# Meine Fragen:
# 1. Räumliche Verteilung der Home-Library-Definition (oder Code) auf einer Landkarte des SF-County,
#     inkl. Within SF County: (true/false)
# 2. Verteilung Notice (Email/Phone/Print/None) zu Year Patron Registered und Altersgruppe.
# 3. Zusammenhang Altersgruppe, Ausleihzahlen und Herkunft.
# 4. Wohnort Kinder und Senioren.
# 5. Menge der Ausleihen an Lehrer, Staff (statistische Verteilungen) gegenüber Adults.
# 6. Bevölkerungsstatistiken SF (extern) korrelieren.
# 7. Provided Email zu Notice (wer hat zwar, will aber nicht) inkl. Altersgruppe?

# %%
sns.relplot(x="Total Checkouts", y="Total Renewals", size="Age Range", data=df)
plt.show()

# %%
sns.pointplot(x="Patron Type Definition",
                  y="Total Checkouts",
hue="Provided Email Address",
data=df,
palette={True:"g",
         False:"m"},
markers=["^","o"],
linestyles=["-","--"])
plt.show()

# %%
df_staff = df.loc[df['Patron Type Definition']=='Staff']
df_teen = df.loc[df['Patron Type Definition']=='Teen']
df_adult = df.loc[df['Patron Type Definition']=='Adult']

# %%
df_teen.mean()
# Out:
# /var/folders/z6/w9xj39b12pb0js3m_zzfqgkh0000gn/T/ipykernel_56877/545237060.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_teen.mean()
# Patron Type Code                  2.000000
# Total Checkouts                 235.112246
# Total Renewals                   69.593778
# Circulation Active Year        2020.910051
# Provided Email Address            0.830045
# Year Patron Registered         2014.424641
# Within San Francisco County       0.900273
# dtype: float64

# %%
df.loc[df['Patron Type Definition']=='Adult'].mean()
# Out:
# /var/folders/z6/w9xj39b12pb0js3m_zzfqgkh0000gn/T/ipykernel_56877/3741721669.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.loc[df['Patron Type Definition']=='Adult'].mean()
# Patron Type Code                  0.000000
# Total Checkouts                 125.744945
# Total Renewals                   68.161053
# Circulation Active Year        2021.758615
# Provided Email Address            0.938513
# Year Patron Registered         2015.061306
# Within San Francisco County       0.825916
# dtype: float64

# %%
plt.style.use('_mpl-gallery')

sns.barplot(x="Age Range",
               y="Total Checkouts",
                hue="Provided Email Address",
data=df)

plt.show()

# %%
df_staff
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 4091                   5                  Staff                0
# 13821                  5                  Staff                0
# 28457                  5                  Staff                0
# 39935                  5                  Staff                0
# 40608                  5                  Staff             4204
# ...                  ...                    ...              ...
# 435586                 5                  Staff              178
# 435674                 5                  Staff              279
# 436429                 5                  Staff               16
# 436533                 5                  Staff              102
# 436599                 5                  Staff               25
#
#         Total Renewals       Age Range Home Library Code  \
# 4091                 0             NaN                b2
# 13821                0             NaN                m8
# 28457                0             NaN                 x
# 39935                0             NaN                 x
# 40608             4584             NaN                p7
# ...                ...             ...               ...
# 435586              76  55 to 59 years                c2
# 435674             136  45 to 54 years                 x
# 436429               0  45 to 54 years                c2
# 436533              55             NaN                yb
# 436599               0             NaN                 x
#
#        Home Library Definition Circulation Active Month  \
# 4091                   Bayview                      NaN
# 13821              Mission Bay                      NaN
# 28457                     Main                      NaN
# 39935                     Main                      NaN
# 40608                  Potrero                  January
# ...                        ...                      ...
# 435586               Chinatown                 November
# 435674                    Main                September
# 436429               Chinatown                  January
# 436533              Bookmobile                  October
# 436599                    Main                     June
#
#         Circulation Active Year Notice Preference Code  \
# 4091                        NaN                      z
# 13821                       NaN                      z
# 28457                       NaN                      z
# 39935                       NaN                      z
# 40608                    2023.0                      z
# ...                         ...                    ...
# 435586                   2014.0                      z
# 435674                   2014.0                      z
# 436429                   2013.0                      z
# 436533                   2012.0                      z
# 436599                   2012.0                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 4091                          Email                    True
# 13821                         Email                    True
# 28457                         Email                    True
# 39935                         Email                    True
# 40608                         Email                    True
# ...                             ...                     ...
# 435586                        Email                    True
# 435674                        Email                    True
# 436429                        Email                    True
# 436533                        Email                    True
# 436599                        Email                    True
#
#         Year Patron Registered  Within San Francisco County
# 4091                      2022                         True
# 13821                     2019                         True
# 28457                     2003                         True
# 39935                     2007                         True
# 40608                     2003                         True
# ...                        ...                          ...
# 435586                    2003                         True
# 435674                    2003                         True
# 436429                    2011                         True
# 436533                    2007                         True
# 436599                    2008                         True
#
# [808 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

#plt.style.use('_mpl-gallery')

# make the data
np.random.seed(3)
y = df_staff['Total Checkouts']
x = df_staff['Year Patron Registered']
a = df_teen['Total Checkouts']
z = df_teen['Year Patron Registered']

# plot
fig, ax = plt.subplots()
fig, bx = plt.subplots()

ax.bar(x, y)
bx.bar(z, a)

plt.show()

# %%
df_age = df['Age Range'].value_counts()
df_age = pd.DataFrame(df_age)
df_age = df_age.sort_values(by='Age Range')
df_age
# Out:
#                    Age Range
# 60 to 64 years         17664
# 75 years and over      18872
# 55 to 59 years         19281
# 20 to 24 years         24484
# 65 to 74 years         31906
# 0 to 9 years           34642
# 45 to 54 years         48752
# 10 to 19 years         67320
# 35 to 44 years         80477
# 25 to 34 years         92790

# %%
import pandas as pd

df = pd.read_csv(
    "../data/Library_Usage.csv", 
    na_values="none"
)
pd.crosstab(
    df['Home Library Definition'],
    df['Year Patron Registered'],
    margins=True
)
# Out:
# Year Patron Registered    2003  2004  2005  2006  2007   2008   2009   2010  \
# Home Library Definition
# Anza                      1194   116   118   166   164    354    209    131
# Bayview                    426    61    91    81   101    227    182    211
# Bernal                    1141   152   121   131   179    195    185    547
# Bookmobile                 126    13    15    17    11     26     34     40
# Chinatown                 2033   208   217   260   260    431    416    419
# Eureka Valley             1448   156   163   175   215    212    330    378
# Excelsior                 1694   115   234   304   289    484    525    534
# Glen Park                 1351   146   155   151   267    377    381    347
# Golden Gate                564    54    70    80    77    138    148     87
# Ingleside                 1135   143   136   139   182    253    389    396
# Main                      8453  1080  1134  1213  1409   2314   2782   2606
# Marina                     982   115    92    85   186    310    327    308
# Merced                    1522   141   168   196   204    344    234    201
# Mission                   2319   309   350   353   452    684    676    710
# Mission Bay                488    67    78   178   211    305    304    302
# Noe Valley                1177   119   126    96   127    427    385    352
# North Beach                916    82   126   125   131    172    246    242
# Ocean View                 274    28    31    35    43     81     98     98
# Ortega                    2122   210   254   302   391    507    472    501
# Park                      1030   108   121   133   168    265    296    160
# Parkside                  1348   126   171   180   175    232    138    214
# Portola                    800   103   104   136   151    230    359    286
# Potrero                    717    98    99    96    91    137    119    373
# Presidio                   834   105   106   138   142    268    276    130
# Richmond                  3082   306   324   355   299    396   1163    880
# Sunset                    2142   214   177   122   339    455    476    484
# Unknown                     34     4     1     0     5      3      4      4
# Visitacion Valley          411    53    57    81   101    159    178    161
# West Portal               2216   200   116   137   429    445    495    503
# Western Addition           924   106   114   114   101    329    271    279
# All                      42903  4738  5069  5579  6900  10760  12098  11884
#
# Year Patron Registered    2011   2012  ...   2014   2015   2016   2017   2018  \
# Home Library Definition                ...
# Anza                       284    314  ...    346    445    396    500    611
# Bayview                    185    167  ...    436    486    455    685    463
# Bernal                     394    382  ...    476    591    585   1046    813
# Bookmobile                  37     61  ...     60     97    101    249    178
# Chinatown                  499    500  ...    552    733    643    971    924
# Eureka Valley              369    427  ...    488    562    528    896    953
# Excelsior                  577    643  ...    687    776    713   1342    930
# Glen Park                  314    317  ...    393    507    452    548    468
# Golden Gate                163    207  ...    266    311    358    506    531
# Ingleside                  394    364  ...    417    470    472    622    608
# Main                      2922   3168  ...   3895   5502   6432   8641   8749
# Marina                     335    369  ...    447    539    595    735    850
# Merced                     338    449  ...    471    540    608    733    679
# Mission                    726    717  ...    931   1165   1075   1609   1537
# Mission Bay                319    377  ...    594    842   1015   1326   1719
# Noe Valley                 327    401  ...    448    510    604    711    728
# North Beach                275    240  ...    487    532    605    675    776
# Ocean View                 112     97  ...    126    160    197    384    308
# Ortega                     738    755  ...    777    820    811    992    981
# Park                       407    356  ...    444    539    638    736    816
# Parkside                   412    297  ...    409    483    558    547    668
# Portola                    246    308  ...    372    380    435    565    523
# Potrero                    230    288  ...    358    494    519    677    845
# Presidio                   352    335  ...    379    516    588    740    805
# Richmond                   807    855  ...   1008   1127   1114   1343   1325
# Sunset                     509    463  ...    576    672    744    829    950
# Unknown                      3      3  ...      3      5      0      7      3
# Visitacion Valley          311    319  ...    332    302    298    601    369
# West Portal                384    411  ...    459    523    490    628    553
# Western Addition           316    318  ...    391    476    522    575    599
# All                      13285  13908  ...  17028  21105  22551  30419  30262
#
# Year Patron Registered    2019   2020   2021   2022     All
# Home Library Definition
# Anza                      1007    345    509    948    8477
# Bayview                    780    216    207    633    6594
# Bernal                    1391    405    596   1189   10882
# Bookmobile                 396     98    133    340    2097
# Chinatown                 1362    305    485   1074   12759
# Eureka Valley             1807    575    752   1373   12190
# Excelsior                 1588    521    590    965   14141
# Glen Park                  760    163    259    615    8294
# Golden Gate               1041    300    459   1051    6591
# Ingleside                 1108    262    268    764    8885
# Main                     19241  21927  18152  20612  143471
# Marina                    1545    595    659   1686   11131
# Merced                    1413    409    458   1031   10544
# Mission                   2825    652    206   1195   19212
# Mission Bay               2757    900   1321   2337   15878
# Noe Valley                1199    380    580   1094   10175
# North Beach               1484    433    630   1657   10126
# Ocean View                 443    143    231    479    3476
# Ortega                    1506    441    721   1384   15423
# Park                      1522    548    800   1732   11138
# Parkside                  1182    344    412    887    9142
# Portola                    649    163    199    533    6890
# Potrero                   1513    488    655   1478    9586
# Presidio                  1401    496    663   1410   10059
# Richmond                  2101    681    965   1766   20736
# Sunset                    1752    480    556   1656   14091
# Unknown                      9      4     14     21     129
# Visitacion Valley          579    159    232    501    5450
# West Portal                989    254    396    916   10901
# Western Addition          1087    312    460   1050    8647
# All                      56437  32999  32568  52377  437115
#
# [31 rows x 21 columns]

# %%
sns.lineplot(x="Year Patron Registered", y="Total Checkouts", 
              data=df_teen)
sns.lineplot(x="Year Patron Registered", y="Total Checkouts", 
            data=df_staff)
plt.show()
